# %% [markdown]
# # In this notebook we'll start working with models hosted on the Huggingface platform!
#
# [This is the link to the main pipeline page](https://huggingface.co/docs/transformers/main_classes/pipelines)

# %% [markdown]
# # Image Classification

# %% [markdown]
# # Object Detection

# %%
# generate with colab ai

# %% [markdown]
# # Zero shot object detection

# %% [markdown]
# # Depth Estimation

# %% [markdown]
# # Image to Image

# %% [markdown]
# # Text Generation

# %% [markdown]
# # Image to text

# %% [markdown]
# # Summerization
